# %%
print("jai shree Ram")
# Out:
# jai shree Ram

# %%
# let's import the matplot liberary
import matplotlib.pyplot as plt

# %% [raw]
# Here matplotlib is libearay and pyplot is a module of it

# %%
import numpy as np

# %%
# let's do little example 
price=np.array([10,12,15,20,25,55,60])
qty=np.array([100,200,120,155,135,140,160])

# %%
# let's plot this
plt.plot(price,qty)

# %%
plt.plot(price,qty);plt.show() # it is use to hide infro visible at the top of graph (generator type infor)

# %%
import pandas as pd

# %%
df=pd.read_excel("C:/Users/admin/Desktop/emp.xlsx")

# %%
df
# Out:
#    sr no      name  designation  age address  sallary
# 0      1  sikandar      manager   20      aa      200
# 1      2      aman  supervioser   30      bb      300
# 2      3     rohan         Peon   10      cc      250
# 3      4     mohan      manager   15      dd      150
# 4      5     sohan  supervioser   18      ee      140
# 5      6      monu         Peon   22      aa      160
# 6      7      sonu      manager   35      bb      240
# 7      8    mukesh  supervioser   25      cc      150
# 8      9     akash         Peon   30      dd      160
# 9     10    akshya      manager   24      ee      190

# %%
plt.plot(df["age"],df["sallary"]);plt.show()

# %%
plt.plot(df["age"],df["sallary"],"-.") # here "-." is use to change the line style

# %%
# change the dot appearence of the graph
plt.plot(df["age"],df["sallary"],"o--") # o is use for change pint visiblity of dot adn

# %%
# let's change the color of line
plt.plot(df["age"],df["sallary"],"o--r") # here r stand for red

# %%
plt.plot(df["age"],df["sallary"],"*-.b")
